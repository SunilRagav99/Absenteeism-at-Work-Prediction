# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\sunil\OneDrive\Desktop\python guvi\MFGEmployees4.csv")
df.head(10)
# Out:
#    EmployeeNumber    Surname GivenName Gender             City  \
# 0               1  Gutierrez     Molly      F          Burnaby
# 1               2   Hardwick   Stephen      M        Courtenay
# 2               3    Delgado   Chester      M         Richmond
# 3               4      Simon     Irene      F         Victoria
# 4               5   Delvalle    Edward      M  New Westminster
# 5               6      Jones     Ernie      M         Richmond
# 6               7     Buford     Ralph      M        Vancouver
# 7               8        Lee   Gregory      M          Sechelt
# 8               9      Smith     Jerry      M  New Westminster
# 9              10      Beard    Robert      M        Vancouver
#
#            JobTitle DepartmentName    StoreLocation              Division  \
# 0             Baker         Bakery          Burnaby                Stores
# 1             Baker         Bakery          Nanaimo                Stores
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeNumber  8336 non-null   int64
#  1   Surname         8336 non-null   object
#  2   GivenName       8336 non-null   object
#  3   Gender          8336 non-null   object
#  4   City            8336 non-null   object
#  5   JobTitle        8336 non-null   object
#  6   DepartmentName  8336 non-null   object
#  7   StoreLocation   8336 non-null   object
#  8   Division        8336 non-null   object
#  9   Age             8336 non-null   float64
#  10  LengthService   8336 non-null   float64
#  11  AbsentHours     8336 non-null   float64
#  12  BusinessUnit    8336 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 846.8+ KB

# %%
# maximum value of the 'AbsentHours' column
print(f"Higher hours of absents: {df['AbsentHours'].max()}")

# Count the number of unique employees
unique_employee_count = len(df['EmployeeNumber'].unique())
print(f"Unique employee count: {unique_employee_count}")

# the shape of the DataFrame
print(f"DataFrame shape: {df.shape}")

#column names
print(f"Column names:{df.columns}")
# Out:
# Higher hours of absents: 272.5301234
# Unique employee count: 8336
# DataFrame shape: (8336, 13)
# Column names:Index(['EmployeeNumber', 'Surname', 'GivenName', 'Gender', 'City', 'JobTitle',
#        'DepartmentName', 'StoreLocation', 'Division', 'Age', 'LengthService',
#        'AbsentHours', 'BusinessUnit'],
#       dtype='object')

# %%
print(df.isna().sum())
# Out:
# EmployeeNumber    0
# Surname           0
# GivenName         0
# Gender            0
# City              0
# JobTitle          0
# DepartmentName    0
# StoreLocation     0
# Division          0
# Age               0
# LengthService     0
# AbsentHours       0
# BusinessUnit      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot for DepartmentName
plt.figure(figsize=(20, 10))
sns.scatterplot(x=df['DepartmentName'], y=df['AbsentHours'])
plt.xticks(rotation=90)
plt.title('Absent Hours by Department')
plt.xlabel('Department Name')
plt.ylabel('Absent Hours')
plt.show()

# Scatter plot for JobTitle
plt.figure(figsize=(20, 10))
sns.scatterplot(x=df['JobTitle'], y=df['AbsentHours'])
plt.xticks(rotation=90)
plt.title('Absent Hours by Job Title')
plt.xlabel('Job Title')
plt.ylabel('Absent Hours')
plt.show()

# %%
import numpy as np
def check(df,columns):
    condition=(df[columns]=="")|(df[columns]==" ")
    df.loc[condition,columns]=np.NaN

# %%
check(df,'EmployeeNumber')
check(df, 'Surname')
check(df, 'GivenName')
check(df, 'Gender')
check(df, 'City')
check(df, 'JobTitle')
check(df,'DepartmentName')
check(df, 'StoreLocation')
check(df, 'Division')
check(df, 'Age')
check(df, 'LengthService')
check(df,'AbsentHours')
check(df, 'BusinessUnit')

# %%
print(df.isna().sum())
# Out:
# EmployeeNumber    0
# Surname           0
# GivenName         0
# Gender            0
# City              0
# JobTitle          0
# DepartmentName    0
# StoreLocation     0
# Division          0
# Age               0
# LengthService     0
# AbsentHours       0
# BusinessUnit      0
# dtype: int64

# %%
def unique(df,column):
    print(df[column].value_counts())

# %%
unique(df,"JobTitle")
unique(df, 'Gender')
unique(df, 'City')
unique(df,'DepartmentName')
unique(df, 'StoreLocation')
unique(df, 'Division')
unique(df, 'Age')
unique(df, 'LengthService')
unique(df,'AbsentHours')
unique(df, 'BusinessUnit')
# Out:
# JobTitle
# Cashier                            1703
# Dairy Person                       1514
# Meat Cutter                        1480
# Baker                              1404
# Produce Clerk                      1129
# Shelf Stocker                       712
# Bakery Manager                       45
# Store Manager                        39
# Customer Service Manager             34
# Processed Foods Manager              34
# Produce Manager                      34
# Meats Manager                        34
# Accounting Clerk                     17
# Accounts Receiveable Clerk           15
# Accounts Payable Clerk               14
# Auditor                              14
# Trainer                              14
# HRIS Analyst                         13
# Recruiter                            13
# Benefits Admin                       11
# Labor Relations Analyst              11
# Systems Analyst                      10
# Compensation Analyst                  8
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Filter only numeric columns for correlation matrix calculation
numeric_df = df.select_dtypes(include=[float, int])

# Calculate the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
print(df["JobTitle"].unique().shape)
# Out:
# (47,)

# %%
# def histplot(df,column):
#     unique_job_titles = df[column].unique()
#     filtered_df = df[df[column].isin(unique_job_titles)]

#     plt.figure(figsize=(16, 6))
#     sns.barplot(data=filtered_df, x=column, y="AbsentHours")
#     plt.xticks(rotation=90) 
#     plt.show()

# %%
# histplot(df,"LengthService")

# %%
import matplotlib.pyplot as plt

# Plot histogram for the 'Age' column
# Adjust the size as needed
df['Age'].hist(bins=30, color='r')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Filter rows where Age is greater than 20 and less than 60
filtered_df = df[(df["Age"] > 18) & (df["Age"] < 60)]

# Print the filtered DataFrame
display(filtered_df)

# Print the number of rows in the filtered DataFrame
print(f"length of the filtered dataframe: {len(filtered_df)}")
# Out:
#       EmployeeNumber    Surname GivenName Gender             City  \
# 0                1.0  Gutierrez     Molly      F          Burnaby
# 1                2.0   Hardwick   Stephen      M        Courtenay
# 2                3.0    Delgado   Chester      M         Richmond
# 3                4.0      Simon     Irene      F         Victoria
# 4                5.0   Delvalle    Edward      M  New Westminster
# ...              ...        ...       ...    ...              ...
# 8331          8332.0   Coniglio    Bianca      F          Langley
# 8332          8333.0        Cox    Jimmie      M          Montney
# 8333          8334.0    Hawkins      Mary      F   West Vancouver
# 8334          8335.0    Proctor   Theresa      F        Vancouver
# 8335          8336.0     Salter   Charles      M        Vancouver
#
#           JobTitle    DepartmentName    StoreLocation Division        Age  \
# 0            Baker            Bakery          Burnaby   Stores  32.028816
# ...

# %%
#outlier detection
sns.boxplot(df["AbsentHours"])
plt.show()
print("Mean=",np.mean(df["AbsentHours"]))
print("Medium=",np.median(df["AbsentHours"]))
# Out:
# c:\Users\sunil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Mean= 61.28397768261564
# Medium= 56.005807515

# %%
# It is clear that half of the employee is absent for less than 56 hrs.

# There are few employees which are absent for days which make mean 61 hrs.

# %%
df
# Out:
#       EmployeeNumber    Surname GivenName Gender             City  \
# 0                1.0  Gutierrez     Molly      F          Burnaby
# 1                2.0   Hardwick   Stephen      M        Courtenay
# 2                3.0    Delgado   Chester      M         Richmond
# 3                4.0      Simon     Irene      F         Victoria
# 4                5.0   Delvalle    Edward      M  New Westminster
# ...              ...        ...       ...    ...              ...
# 8331          8332.0   Coniglio    Bianca      F          Langley
# 8332          8333.0        Cox    Jimmie      M          Montney
# 8333          8334.0    Hawkins      Mary      F   West Vancouver
# 8334          8335.0    Proctor   Theresa      F        Vancouver
# 8335          8336.0     Salter   Charles      M        Vancouver
#
#           JobTitle    DepartmentName    StoreLocation Division        Age  \
# 0            Baker            Bakery          Burnaby   Stores  32.028816
# ...

# %%
df.Division.unique()
# df.BusinessUnit.unique()
# Out:
# array(['Stores', 'FinanceAndAccounting', 'HumanResources', 'InfoTech',
#        'Executive', 'Legal'], dtype=object)

# %%
dff=df.copy()

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import labelencoder
onehotencoder=OneHotEncoder()
dff[['JobTitle',"DepartmentName","Division","BusinessUnit"]]=ordinalencoder.fit_transform(dff[['JobTitle',"DepartmentName","Division","BusinessUnit"]])

# %%
len(dff["City"].unique())
# Out:
# 243

# %%
len(dff["StoreLocation"].unique())
# Out:
# 40

# %%
dff
# Out:
#       EmployeeNumber    Surname GivenName Gender             City  JobTitle  \
# 0                1.0  Gutierrez     Molly      F          Burnaby       4.0
# 1                2.0   Hardwick   Stephen      M        Courtenay       4.0
# 2                3.0    Delgado   Chester      M         Richmond       4.0
# 3                4.0      Simon     Irene      F         Victoria       4.0
# 4                5.0   Delvalle    Edward      M  New Westminster       4.0
# ...              ...        ...       ...    ...              ...       ...
# 8331          8332.0   Coniglio    Bianca      F          Langley       9.0
# 8332          8333.0        Cox    Jimmie      M          Montney       9.0
# 8333          8334.0    Hawkins      Mary      F   West Vancouver       9.0
# 8334          8335.0    Proctor   Theresa      F        Vancouver      14.0
# 8335          8336.0     Salter   Charles      M        Vancouver      14.0
#
# ...

# %%
dff["log_absent"]=np.log(dff["AbsentHours"])
# Out:
# c:\Users\sunil\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
dff.loc[np.isneginf(dff['log_absent']), 'log_absent'] = 0

# %%
X=dff[["Age","Gender","City","JobTitle","DepartmentName","StoreLocation","Division","LengthService","BusinessUnit"]]

# %%
y=dff["log_absent"]

# %%
X
# Out:
#             Age Gender             City  JobTitle  DepartmentName  \
# 0     32.028816      F          Burnaby       4.0             4.0
# 1     40.320902      M        Courtenay       4.0             4.0
# 2     48.822047      M         Richmond       4.0             4.0
# 3     44.599357      F         Victoria       4.0             4.0
# 4     35.697876      M  New Westminster       4.0             4.0
# ...         ...    ...              ...       ...             ...
# 8331  46.057544      F          Langley       9.0             6.0
# 8332  34.455490      M          Montney       9.0             6.0
# 8333  58.347160      F   West Vancouver       9.0             6.0
# 8334  43.340616      F        Vancouver      14.0             7.0
# 8335  46.192782      M        Vancouver      14.0             7.0
#
#         StoreLocation  Division  LengthService  BusinessUnit
# 0             Burnaby       5.0       6.018478           1.0
# ...

# %%
y
# Out:
# 0       3.599428
# 1       3.406685
# 2       4.428526
# 3       4.248783
# 4       0.000000
#           ...
# 8331    4.539726
# 8332    0.000000
# 8333    5.172510
# 8334    4.099696
# 8335    4.718708
# Name: log_absent, Length: 8336, dtype: float64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
onehotencoder=OneHotEncoder()
ordinalencoder=OrdinalEncoder()
dff[['JobTitle',"DepartmentName","Division","BusinessUnit"]]=ordinalencoder.fit_transform(dff[['JobTitle',"DepartmentName","Division","BusinessUnit"]])
dff[["Gender","City","StoreLocation"]]=ordinalencoder.fit_transform(dff[["Gender","City","StoreLocation"]])
X=dff[["Age","Gender","City","JobTitle","DepartmentName","StoreLocation","Division","LengthService","BusinessUnit"]]
y=dff["log_absent"]

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Initialize and fit SelectKBest
selector = SelectKBest(score_func=f_classif, k='all')
selector.fit(X, y)

# Get scores and p-values
scores = selector.scores_
p_values = selector.pvalues_

# Create a DataFrame for feature scores
scores_df = pd.DataFrame({
    'Feature': X.columns,
    'Score': scores,
    'P-Value': p_values
})

# Sort by score
print("Feature scores:")
print(scores_df.sort_values(by='Score', ascending=False))
# Out:
# Feature scores:
#           Feature     Score       P-Value
# 0             Age  2.112817  4.997464e-59
# 2            City  1.031110  2.389148e-01
# 1          Gender  1.004816  4.587833e-01
# 3        JobTitle  0.983809  6.536031e-01
# 5   StoreLocation  0.979776  6.887432e-01
# 4  DepartmentName  0.971801  7.536351e-01
# 8    BusinessUnit  0.438454  1.000000e+00
# 6        Division  0.407058  1.000000e+00
# 7   LengthService  0.371443  1.000000e+00

# %%
from sklearn.preprocessing import StandardScaler
standcondition=StandardScaler()
X=standcondition.fit_transform(X)

# %%
X
# Out:
# array([[-1.00393073, -1.0115834 , -1.75326108, ...,  0.14201305,
#          0.50168423,  0.14557881],
#        [-0.16964984,  0.98854924, -1.43340499, ...,  0.14201305,
#          0.30433746,  0.14557881],
#        [ 0.68566482,  0.98854924,  0.34666369, ...,  0.14201305,
#         -0.15954595,  0.14557881],
#        ...,
#        [ 1.64400274, -1.0115834 ,  1.02809623, ...,  0.14201305,
#         -0.31407498,  0.14557881],
#        [ 0.13416871, -1.0115834 ,  0.94465551, ...,  0.14201305,
#          0.55705045,  0.14557881],
#        [ 0.42113002,  0.98854924,  0.94465551, ...,  0.14201305,
#          0.15908945,  0.14557881]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5001, 9)
# (3335, 9)
# (5001,)
# (3335,)

# %%
# regressor

# %%
from sklearn.linear_model import LinearRegression
LinearR=LinearRegression()
LinearR.fit(X_train,y_train)
print(LinearR.score(X_train,y_train))
print(LinearR.score(X_test,y_test))
y_predict=LinearR.predict(X_test)

# Calculate the Mean Squared Error
mse = mean_squared_error(y_test, y_predict)
print(f'Mean Squared Error: {mse}')

#Calculate the root Mean Squared Error
rmse=np.sqrt(mse)
print(f"RMSE:{rmse}")

# Calculate the R-squared score
r2 = r2_score(y_test, y_predict)
print(f'R-squared: {r2}')
# Out:
# 0.5990113532086581
# 0.5851244699532246
# Mean Squared Error: 1.1685673164586823
# RMSE:1.0810029215773111
# R-squared: 0.5851244699532246

# %%
from sklearn.decomposition import PCA
PCAMLR=LinearRegression()
pca = PCA(n_components=9)  
X_pca = pca.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.4, random_state=42)

# Create and fit MLR PCA model
PCAMLR = LinearRegression()
PCAMLR.fit(X_train, y_train)

# Make predictions
y_pred = PCAMLR.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
#Calculate the root Mean Squared Error
rmse=np.sqrt(mse)
print(f"RMSE:{rmse}")
print(f'R-squared: {r2}')
# Print the model coefficients
# print("Intercept:", PCAMLR.intercept_)
# print("Coefficients:", PCAMLR.coef_)
# Out:
# Mean Squared Error: 1.2214424646605555
# RMSE:1.105188881893297
# R-squared: 0.5709416857586225

# %%
from sklearn.ensemble import RandomForestRegressor
RFR=RandomForestRegressor(n_estimators=250)
RFR.fit(X_train,y_train)
y_pred_RFR=RFR.predict(X_test)
mse = mean_squared_error(y_test, y_pred_RFR)
r2 = r2_score(y_test, y_pred_RFR)
print(f'Mean Squared Error: {mse}')
#Calculate the root Mean Squared Error
rmse=np.sqrt(mse)
print(f"RMSE:{rmse}")
print(f'R-squared: {r2}')
print(np.exp(y_pred_RFR))
# Out:
# Mean Squared Error: 1.0400679018684358
# RMSE:1.0198371938051856
# R-squared: 0.6346534580355756
# [163.4447345    3.76996161   2.74019956 ...  11.37027086   1.01009636
#  109.41386693]

# %%
from sklearn.decomposition import PCA
PCARFR=LinearRegression()
pcaRLR = PCA(n_components=9)  
X_pcaRLR = pcaRLR.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_pcaRLR, y, test_size=0.4, random_state=42)

# Create and fit MLR pCA model
RFRPCA=RandomForestRegressor(n_estimators=500)
RFRPCA.fit(X_train, y_train)

# Make predictions
y_pred_RFRPCA = RFRPCA.predict(X_test)

# Evaluate the model
msePLARFR = mean_squared_error(y_test, y_pred_RFRPCA)
r2PLARFR = r2_score(y_test, y_pred_RFRPCA)
print(f'Mean Squared Error: {msePLARFR}')
#Calculate the root Mean Squared Error
rmse=np.sqrt(msePLARFR)
print(f"RMSE:{rmse}")
print(f'R-squared: {r2PLARFR}')
# Print the model coefficients
# Out:
# Mean Squared Error: 1.0348127805476084
# RMSE:1.0172574799664087
# R-squared: 0.636499434051871

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

# Example parameter grid
param_grid = {
    'n_estimators': [100, 500],
    'max_depth': [10, 40],
    'min_samples_split': [2, 30],
    'min_samples_leaf': [1, 20],
    'bootstrap': [True]
}

# Initialize model
RFR = RandomForestRegressor()

# Initialize GridSearchCV with error_score='raise'
grid_search = GridSearchCV(estimator=RFR, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, error_score='raise')

# Fit GridSearchCV
try:
    grid_search.fit(X_train, y_train)
except ValueError as e:
    print(f"Error: {e}")

# Output the best parameters if successful
if grid_search.best_params_:
    print(f'Best Parameters: {grid_search.best_params_}')
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    print(f'Mean Squared Error: {mse}')
    print(f'Root Mean Squared Error: {rmse}')
    print(f'R-squared: {r2}')
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 40, 'min_samples_leaf': 20, 'min_samples_split': 2, 'n_estimators': 100}
# Mean Squared Error: 1.0047992073671428
# Root Mean Squared Error: 1.0023967315225757
# R-squared: 0.6470423564454768

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score

pcaRLRH = PCA(n_components=9)  
X_pcaRLRH = pcaRLRH.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_pcaRLRH, y, test_size=0.4, random_state=42)

# Create and fit MLR pCA model
RFRPCA=RandomForestRegressor()
RFRPCA.fit(X_train, y_train)


# Example parameter grid
param_grid = {
    'n_estimators': [100, 500],
    'max_depth': [10, 40],
    'min_samples_split': [2, 30],
    'min_samples_leaf': [1, 20],
    'bootstrap': [True]
}

# Initialize model
RFR = RandomForestRegressor()

# Initialize GridSearchCV with error_score='raise'
grid_search = GridSearchCV(estimator=RFR, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, error_score='raise')

# Fit GridSearchCV
try:
    grid_search.fit(X_train, y_train)
except ValueError as e:
    print(f"Error: {e}")

# Output the best parameters if successful
if grid_search.best_params_:
    print(f'Best Parameters: {grid_search.best_params_}')
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    print(f'Mean Squared Error: {mse}')
    print(f'Root Mean Squared Error: {rmse}')
    print(f'R-squared: {r2}')
    print(grid_search.predict(X_test))
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 30, 'n_estimators': 100}
# Mean Squared Error: 1.0064920569854232
# Root Mean Squared Error: 1.0032407771743648
# R-squared: 0.6464477060837135
# [5.12599678e+00 1.06211550e+00 3.95098460e-01 ... 2.82286205e+00
#  3.22348792e-03 4.64865950e+00]

# %%
from sklearn.ensemble import ExtraTreesRegressor
ET=ExtraTreesRegressor(n_estimators=100, random_state=42)
ET.fit(X_train, y_train)

y_pred_ET = ET.predict(X_test)

# Evaluate the model
mseET = mean_squared_error(y_test, y_pred_ET)
r2ET = r2_score(y_test, y_pred_ET)
print(f'Mean Squared Error: {mseET}')
#Calculate the root Mean Squared Error
rmse=np.sqrt(mseET)
print(f"RMSE:{rmse}")
print(f'R-squared: {r2ET}')
# Out:
# Mean Squared Error: 1.091731112201051
# RMSE:1.0448593743662593
# R-squared: 0.6165056282564876

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_selection import SelectKBest, f_regression
import pandas as pd

# Assuming df is your DataFrame and 'target' is the name of the target variable
X = dff.drop(columns=["log_absent"])
y = dff["log_absent"]

# Select the best features
best_features = SelectKBest(score_func=f_regression, k=10)
X_best = best_features.fit_transform(X, y)

# Perform PCA
pcaRLRH = PCA(n_components=9)  
X_pcaRLRH = pcaRLRH.fit_transform(X_best)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_pcaRLRH, y, test_size=0.4, random_state=42)

# Create and fit the initial RandomForestRegressor PCA model
RFRPCA = RandomForestRegressor()
RFRPCA.fit(X_train, y_train)

# Example parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [100, 500],
    'max_depth': [10, 40],
    'min_samples_split': [2, 30],
    'min_samples_leaf': [1, 20],
    'bootstrap': [True]
}

# Initialize GridSearchCV
RFR = RandomForestRegressor()
grid_search = GridSearchCV(estimator=RFR, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2, error_score='raise')

# Fit GridSearchCV
try:
    grid_search.fit(X_train, y_train)
except ValueError as e:
    print(f"Error: {e}")

# Output the best parameters if successful
if hasattr(grid_search, 'best_params_'):
    print(f'Best Parameters: {grid_search.best_params_}')
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    print(f'Mean Squared Error: {mse}')
    print(f'Root Mean Squared Error: {rmse}')
    print(f'R-squared: {r2}')
    print(grid_search.predict(X_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23304\2488450889.py in ?()
#      11 y = dff["log_absent"]
#      12
#      13 # Select the best features
#      14 best_features = SelectKBest(score_func=f_regression, k=10)
# ---> 15 X_best = best_features.fit_transform(X, y)
#      16
#      17 # Perform PCA
#      18 pcaRLRH = PCA(n_components=9)
#
# c:\Users\sunil\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# ...
